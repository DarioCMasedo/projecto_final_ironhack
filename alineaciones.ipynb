# %%
import matplotlib.pyplot as plt

from mplsoccer import Pitch

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import *
from sklearn import model_selection
from sklearn import ensemble
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsRegressor
import seaborn as sns
import pickle
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score

# %%
from mplsoccer.pitch import Pitch

# %%
from mplsoccer.pitch import Pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
annotation = ax.annotate('aaa', (5, 40), fontsize=30, ha='center')
fig, ax = pitch.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d8552703c33b> in <module>
#       1 from mplsoccer.pitch import Pitch
#       2 pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
# ----> 3 annotation = ax.annotate('aaa', (5, 40), fontsize=30, ha='center')
#       4 fig, ax = pitch.draw()
#
# NameError: name 'ax' is not defined

# %%
from src.funciones import goalkeeper, defenders, midfielders, forwards

# %%
def alineacion_442(valor_total,edad):
    valor_jugador = valor_total/11
    porteros = goalkeeper(1,valor_jugador,edad).reset_index()
    defensas = defenders(4,valor_jugador,edad).reset_index()
    medios = midfielders(4,valor_jugador,edad).reset_index()
    delanteros = forwards(2,valor_jugador,edad).reset_index()
    pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
    fig, ax = pitch.draw(figsize=(10, 20))
    annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][0], (24, 30), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][1], (24, 52), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][2], (32, 12), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][3], (32, 68), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][0], (60, 30), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][1], (60, 52), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][2], (60, 12), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][3], (60, 68), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][0], (89, 24), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][1], (89, 60), fontsize=20, ha='center')
    return ax

# %%
alineacion_442(100000000, 35)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def alineacion_433(valor_total,edad):
    try:
        valor_jugador = valor_total/11
        porteros = goalkeeper(1,valor_jugador,edad).reset_index()
        defensas = defenders(4,valor_jugador,edad).reset_index()
        medios = midfielders(3,valor_jugador,edad).reset_index()
        delanteros = forwards(3,valor_jugador,edad).reset_index()
        pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
        fig, ax = pitch.draw(figsize=(10, 20))
        annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][0], (24, 30), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][1], (24, 52), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][2], (32, 12), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][3], (32, 68), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][0], (60, 12), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][1], (60, 40), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][2], (89, 40), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][0], (60, 68), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][1], (89, 12), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][2], (89, 68), fontsize=20, ha='center')
        return ax
    except:
        print("Valores erroneos")

# %%
alineacion_433(1000000000000000000, 35)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def alineacion_343(valor_total,edad):
    valor_jugador = valor_total/11
    porteros = goalkeeper(1,valor_jugador,edad).reset_index()
    defensas = defenders(3,valor_jugador,edad).reset_index()
    medios = midfielders(4,valor_jugador,edad).reset_index()
    delanteros = forwards(3,valor_jugador,edad).reset_index()
    pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
    fig, ax = pitch.draw(figsize=(10, 20))
    annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][0], (89, 40), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][1], (24, 40), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][2], (32, 12), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][0], (32, 68), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][1], (60, 30), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][2], (60, 52), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][3], (60, 12), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][0], (60, 68), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][1], (89, 12), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][2], (89, 68), fontsize=20, ha='center')
    return ax

# %%
alineacion_343(100000000, 35)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def alineacion_532(valor_total,edad):
    valor_jugador = valor_total/11
    porteros = goalkeeper(1,valor_jugador,edad).reset_index()
    defensas = defenders(5,valor_jugador,edad).reset_index()
    medios = midfielders(3,valor_jugador,edad).reset_index()
    delanteros = forwards(2,valor_jugador,edad).reset_index()
    pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
    fig, ax = pitch.draw(figsize=(10, 20))
    annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][0], (24, 20), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][1], (24, 40), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][2], (35, 8), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][3], (35, 72), fontsize=20, ha='center')
    annotation = ax.annotate(defensas['short_name'][4], (24, 60), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][0], (60, 40), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][1], (60, 12), fontsize=20, ha='center')
    annotation = ax.annotate(medios['short_name'][2], (60, 68), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][0], (89, 24), fontsize=20, ha='center')
    annotation = ax.annotate(delanteros['short_name'][1], (89, 60), fontsize=20, ha='center')
    return ax

# %%
alineacion_532(1000000, 35)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
porteros = pd.read_csv('output/predict_posiciones/porteros.csv')
gk = porteros.loc[(porteros['value_pred'] <= 500000) & (porteros['age'] <= 35)]
gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
gk = gk.nlargest(1, columns="value_pred")
# Out:
# <ipython-input-16-d4b04b41597e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)

# %%
gk.sort_values(by = 'value_pred', inplace = True, ascending = False)

# %%
gk
# Out:
#       Unnamed: 0 short_name nationality     club  age  wage_eur  value_eur  \
# 1064       11364    A. Dini       Italy  Trapani   23      1000     500000
#
#       gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 1064       64.0         62.0        59.0         67.0      28.0
#
#       gk_positioning  value_pred
# 1064            66.0    499625.0

# %%
def alineacion_442(valor_total,edad):
    try:
        valor_jugador = valor_total/11
        porteros = goalkeeper(1,valor_jugador,edad).reset_index()
        defensas = defenders(4,valor_jugador,edad).reset_index()
        medios = midfielders(4,valor_jugador,edad).reset_index()
        delanteros = forwards(2,valor_jugador,edad).reset_index()
        pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
        fig, ax = pitch.draw(figsize=(10, 20))
        annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][0], (24, 30), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][1], (24, 52), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][2], (32, 12), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][3], (32, 68), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][0], (60, 30), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][1], (60, 52), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][2], (60, 12), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][3], (60, 68), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][0], (89, 24), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][1], (89, 60), fontsize=20, ha='center')
        return fig
    except:
        print("Valores erroneos")

# %%
alineacion_442(1000000,33)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def alineacion_442(valor_total,edad):
    try:
        valor_jugador = valor_total/11
        porteros = goalkeeper(1,valor_jugador,edad).reset_index()
        defensas = defenders(4,valor_jugador,edad).reset_index()
        medios = midfielders(4,valor_jugador,edad).reset_index()
        delanteros = forwards(2,valor_jugador,edad).reset_index()
        pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
        fig, ax = pitch.draw(figsize=(10, 20))
        annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][0], (24, 30), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][1], (24, 52), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][2], (32, 12), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][3], (32, 68), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][0], (60, 30), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][1], (60, 52), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][2], (60, 12), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][3], (60, 68), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][0], (89, 24), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][1], (89, 60), fontsize=20, ha='center')
        return plt.savefig('image.jpg')
    except:
        print("Valores erroneos")

# %%
alineacion_442(100000000, 25)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def alineacion_442(valor_total,edad):
    try:
        valor_jugador = valor_total/11
        porteros = goalkeeper(1,valor_jugador,edad).reset_index()
        defensas = defenders(4,valor_jugador,edad).reset_index()
        medios = midfielders(4,valor_jugador,edad).reset_index()
        delanteros = forwards(2,valor_jugador,edad).reset_index()
        pitch = Pitch(pitch_color='grass', line_color='white',stripe=True)
        fig, ax = pitch.draw(figsize=(10, 20))
        annotation = ax.annotate(porteros['short_name'][0], (5, 40), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][0], (24, 30), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][1], (24, 52), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][2], (32, 12), fontsize=20, ha='center')
        annotation = ax.annotate(defensas['short_name'][3], (32, 68), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][0], (60, 30), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][1], (60, 52), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][2], (60, 12), fontsize=20, ha='center')
        annotation = ax.annotate(medios['short_name'][3], (60, 68), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][0], (89, 24), fontsize=20, ha='center')
        annotation = ax.annotate(delanteros['short_name'][1], (89, 60), fontsize=20, ha='center')
        plt.savefig('image.jpg')
        result = pd.concat([porteros, defensas,medios,delanteros])
        return result
    except:
        print("Valores erroneos")

# %%
alineacion_442(1000000000000,34)
# Out:
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defend.sort_values(by = 'value_pred', inplace = True, ascending = False)
# C:\Users\Dario\Desktop\projecto_final\src\funciones.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
porteros = pd.read_csv('output/predict_posiciones/porteros.csv')
defensas = pd.read_csv('output/predict_posiciones/defensas.csv')
medios = pd.read_csv('output/predict_posiciones/medios.csv')
delanteros = pd.read_csv('output/predict_posiciones/delanteros.csv')
